# %%
import os 
import pandas as pd

# %%
PATH_FOLDER = os.path.join(os.getcwd(), r"C:\Users\Lenovo\Desktop\Master Data Science - Nuclio Digital School\Projects\TimeSeries\Data")

daily_calendar_with_events = os.path.join(PATH_FOLDER, 'daily_calendar_with_events.csv')
item_prices = os.path.join(PATH_FOLDER, 'item_prices.csv')
item_sales = os.path.join(PATH_FOLDER, 'item_sales.csv')

df_events = pd.read_csv(daily_calendar_with_events)
df_prices = pd.read_csv(item_prices)
df_sales = pd.read_csv(item_sales)

print(df_events)

df_sales 

df_prices = df_prices.sample(1000000)
# Out:
#             date    weekday  weekday_int       d event
# 0     2011-01-29   Saturday            1     d_1   NaN
# 1     2011-01-30     Sunday            2     d_2   NaN
# 2     2011-01-31     Monday            3     d_3   NaN
# 3     2011-02-01    Tuesday            4     d_4   NaN
# 4     2011-02-02  Wednesday            5     d_5   NaN
# ...          ...        ...          ...     ...   ...
# 1908  2016-04-20  Wednesday            5  d_1909   NaN
# 1909  2016-04-21   Thursday            6  d_1910   NaN
# 1910  2016-04-22     Friday            7  d_1911   NaN
# 1911  2016-04-23   Saturday            1  d_1912   NaN
# 1912  2016-04-24     Sunday            2  d_1913   NaN
#
# [1913 rows x 5 columns]

# %%
df_events.drop_duplicates(inplace=True)

df_prices.drop_duplicates(inplace=True)

df_sales.drop_duplicates(inplace=True)

# %%
# Utilizar la función melt para convertir las columnas d en observaciones
df_sales_melt = pd.melt(df_sales, id_vars=['id','item','category','department','store','store_code','region'], var_name='d', value_name='sales')

# Utilizar la función sort_values para ordenar el dataframe en base a las otras filas
df_sales_sorted = df_sales_melt.sort_values(by=['id','item','category','department','store','store_code','region','d'])

# Utilizar la función rename para renombrar la columna resultante
df_sales_final = df_sales_sorted.rename(columns={'sales': 'a'})

# Mostrar las columnas requeridas ['id','item','category','department','store','store_code','region', 'd']
df_sales_final = df_sales_final[['id','item','category','department','store','store_code','region', 'd']]

df_sales_final
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Utilizar la función melt para convertir las columnas d en observaciones
# ----> 2 df_sales_melt = pd.melt(df_sales, id_vars=['id','item','category','department','store','store_code','region'], var_name='d', value_name='sales')
#       4 # Utilizar la función sort_values para ordenar el dataframe en base a las otras filas
#       5 df_sales_sorted = df_sales_melt.sort_values(by=['id','item','category','department','store','store_code','region','d'])
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\melt.py:132, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     130 mdata = {}
#     131 for col in id_vars:
# --> 132     id_data = frame.pop(col)
#     133     if is_extension_array_dtype(id_data):
#     134         if K > 0:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5682, in DataFrame.pop(self, item)
#    5641 def pop(self, item: Hashable) -> Series:
#    5642     """
#    5643     Return item and drop from frame. Raise KeyError if not found.
#    5644
#    (...)
#    5680     3  monkey        NaN
#    5681     """
# -> 5682     return super().pop(item=item)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:924, in NDFrame.pop(self, item)
#     922 def pop(self, item: Hashable) -> Series | Any:
#     923     result = self[item]
# --> 924     del self[item]
#     926     return result
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4244, in NDFrame.__delitem__(self, key)
#    4239 if not deleted:
#    4240     # If the above loop ran and didn't delete anything because
#    4241     # there was no match, this call should raise the appropriate
#    4242     # exception:
#    4243     loc = self.axes[-1].get_loc(key)
# -> 4244     self._mgr = self._mgr.idelete(loc)
#    4246 # delete from the caches
#    4247 try:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1480, in BlockManager.idelete(self, indexer)
#    1478 is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#    1479 is_deleted[indexer] = True
# -> 1480 taker = (~is_deleted).nonzero()[0]
#    1482 nbs, new_refs = self._slice_take_blocks_ax0(taker, only_slice=True)
#    1483 new_columns = self.items[~is_deleted]
#
# KeyboardInterrupt:

# %%
df_sales_final.to_csv(r'C:\Users\Lenovo\Desktop\Master Data Science - Nuclio Digital School\Projects\TimeSeries\Data\df_sales_final.csv')

# %%
df_sales_final = pd.read_csv(r'C:\Users\Lenovo\Desktop\Master Data Science - Nuclio Digital School\Projects\TimeSeries\Data\df_sales_final.csv', index_col=0)

# %%
df_sales_final = df_sales_final.sample(1000000)

# %%
df_1 = df_sales_final.merge(df_events, on="d")

# %%
df_1.drop(['event'], axis=1, inplace=True)

# %%
df_1 = df_1.sample(300000)

# %%
df_prices = df_prices.sample(300000)

# %%
df_merged = df_1.merge(df_prices, on='item')
# Out:
#                                  id                 item     category_x  \
# 0           SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235    SUPERMARKET
# 1           SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235    SUPERMARKET
# 2           SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235    SUPERMARKET
# 3           SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235    SUPERMARKET
# 4           SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235    SUPERMARKET
# ...                             ...                  ...            ...
# 29529252  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047  HOME_&_GARDEN
# 29529253  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047  HOME_&_GARDEN
# 29529254  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047  HOME_&_GARDEN
# 29529255  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047  HOME_&_GARDEN
# 29529256  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047  HOME_&_GARDEN
#
#                department      store store_code_x  region       d        date  \
# 0           SUPERMARKET_3  South_End        BOS_1  Boston  d_1108  2014-02-09
# 1           SUPERMARKET_3  South_End        BOS_1  Boston  d_1108  2014-02-09
# 2           SUPERMARKET_3  South_End        BOS_1  Boston  d_1108  2014-02-09
# 3           SUPERMARKET_3  South_End        BOS_1  Boston  d_1108  2014-02-09
# 4           SUPERMARKET_3  South_End        BOS_1  Boston  d_1108  2014-02-09
# ...                   ...        ...          ...     ...     ...         ...
# 29529252  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston  d_1797  2015-12-30
# 29529253  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston  d_1797  2015-12-30
# 29529254  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston  d_1797  2015-12-30
# 29529255  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston  d_1797  2015-12-30
# 29529256  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston  d_1797  2015-12-30
#
#             weekday  weekday_int     category_y store_code_y  yearweek  \
# 0            Sunday            2    SUPERMARKET        NYC_3  201226.0
# 1            Sunday            2    SUPERMARKET        NYC_1  201338.0
# 2            Sunday            2    SUPERMARKET        BOS_2  201207.0
# 3            Sunday            2    SUPERMARKET        PHI_2  201425.0
# 4            Sunday            2    SUPERMARKET        PHI_3  201346.0
# ...             ...          ...            ...          ...       ...
# 29529252  Wednesday            5  HOME_&_GARDEN        BOS_2  201532.0
# 29529253  Wednesday            5  HOME_&_GARDEN        PHI_1  201443.0
# 29529254  Wednesday            5  HOME_&_GARDEN        PHI_2  201437.0
# 29529255  Wednesday            5  HOME_&_GARDEN        BOS_3  201427.0
# 29529256  Wednesday            5  HOME_&_GARDEN        BOS_1  201448.0
#
#           sell_price
# 0             2.0880
# 1             2.0880
# 2             2.3760
# 3             2.0880
# 4             2.0880
# ...              ...
# 29529252      5.2875
# 29529253      4.9125
# 29529254      4.9125
# 29529255      4.9125
# 29529256      5.2875
#
# [29529257 rows x 15 columns]

# %%
df_merged.to_csv(r'C:\Users\Lenovo\Desktop\Master Data Science - Nuclio Digital School\Projects\TimeSeries\Data\df_merged.csv')
