# %%
import os
import pandas as pd

# %%
PATH_FOLDER = os.path.join(os.getcwd(), r"C:\Users\Lenovo\Desktop\Master Data Science - Nuclio Digital School\Projects\TimeSeries\Data")

merged = os.path.join(PATH_FOLDER, 'df_merged.csv', index_col=0)

df_merged = pd.read_csv(merged)

df_merged
# Out:
#           Unnamed: 0                         id                 item  \
# 0                  0    SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235
# 1                  1    SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235
# 2                  2    SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235
# 3                  3    SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235
# 4                  4    SUPERMARKET_3_235_BOS_1    SUPERMARKET_3_235
# ...              ...                        ...                  ...
# 29529252    29529252  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047
# 29529253    29529253  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047
# 29529254    29529254  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047
# 29529255    29529255  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047
# 29529256    29529256  HOME_&_GARDEN_1_047_BOS_2  HOME_&_GARDEN_1_047
#
#              category_x       department      store store_code_x  region  \
# 0           SUPERMARKET    SUPERMARKET_3  South_End        BOS_1  Boston
# 1           SUPERMARKET    SUPERMARKET_3  South_End        BOS_1  Boston
# 2           SUPERMARKET    SUPERMARKET_3  South_End        BOS_1  Boston
# 3           SUPERMARKET    SUPERMARKET_3  South_End        BOS_1  Boston
# 4           SUPERMARKET    SUPERMARKET_3  South_End        BOS_1  Boston
# ...                 ...              ...        ...          ...     ...
# 29529252  HOME_&_GARDEN  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston
# 29529253  HOME_&_GARDEN  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston
# 29529254  HOME_&_GARDEN  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston
# 29529255  HOME_&_GARDEN  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston
# 29529256  HOME_&_GARDEN  HOME_&_GARDEN_1    Roxbury        BOS_2  Boston
#
#                d        date    weekday  weekday_int     category_y  \
# 0         d_1108  2014-02-09     Sunday            2    SUPERMARKET
# 1         d_1108  2014-02-09     Sunday            2    SUPERMARKET
# 2         d_1108  2014-02-09     Sunday            2    SUPERMARKET
# 3         d_1108  2014-02-09     Sunday            2    SUPERMARKET
# 4         d_1108  2014-02-09     Sunday            2    SUPERMARKET
# ...          ...         ...        ...          ...            ...
# 29529252  d_1797  2015-12-30  Wednesday            5  HOME_&_GARDEN
# 29529253  d_1797  2015-12-30  Wednesday            5  HOME_&_GARDEN
# 29529254  d_1797  2015-12-30  Wednesday            5  HOME_&_GARDEN
# 29529255  d_1797  2015-12-30  Wednesday            5  HOME_&_GARDEN
# 29529256  d_1797  2015-12-30  Wednesday            5  HOME_&_GARDEN
#
#          store_code_y  yearweek  sell_price
# 0               NYC_3  201226.0      2.0880
# 1               NYC_1  201338.0      2.0880
# 2               BOS_2  201207.0      2.3760
# 3               PHI_2  201425.0      2.0880
# 4               PHI_3  201346.0      2.0880
# ...               ...       ...         ...
# 29529252        BOS_2  201532.0      5.2875
# 29529253        PHI_1  201443.0      4.9125
# 29529254        PHI_2  201437.0      4.9125
# 29529255        BOS_3  201427.0      4.9125
# 29529256        BOS_1  201448.0      5.2875
#
# [29529257 rows x 16 columns]
